# %%
## FINAL COMPARISION OF THE ACCURACY SCORES

# %%
import matplotlib.pyplot as plt 
  
# x-coordinates of left sides of bars  
left = [1,2,3]
  
# heights of bars 
height = [88.9, 89.6, 92.35] 
  
# labels for bars 
tick_label = ['K-nearest Neighbour', 'Naive Bayes', 'Logistic Regression'] 
  
# plotting a bar chart 
plt.bar(left, height, tick_label = tick_label, 
        width = 0.5, color = ['red','blue', 'green']) 
plt.ylim(85,95)
  
# naming the x-axis 
plt.xlabel('x - axis') 
# naming the y-axis 
plt.ylabel('y - axis') 
# plot title 
plt.title('Final Accuracy Chart', fontsize=20 ) 
  
# function to show the plot 
plt.show()
